# %%
import pandas as pd
import sys

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

import joblib

import pandas as pd

def load_csv_for_decision_tree(csv_path, target_column):
    """
    Loads a CSV file and returns features (X) and target (y) for scikit-learn.

    Args:
        csv_path (str): Path to the CSV file.
        target_column (str): Name of the target column.

    Returns:
        X (pd.DataFrame): Features.
        y (pd.Series): Target variable.
    """

    df = pd.read_csv(csv_path).drop(columns=["patientID"])
    X = df.drop(columns=[target_column])
    y = df[target_column]
    return X, y

def encode_categorical_columns(df):
    """
    Encodes all string (object or category) columns in the DataFrame with unique integer codes.
    Returns a new DataFrame with encoded columns and a dictionary mapping columns to their value mappings.
    """
    encoded_df = df.copy()
    mappings = {}
    for col in encoded_df.select_dtypes(include=['object', 'category']).columns:
        encoded_df[col], uniques = pd.factorize(encoded_df[col])
        mappings[col] = dict(enumerate(uniques))
    return encoded_df, mappings

[raw, expected] = load_csv_for_decision_tree("MP2PRTWT.clinical.csv", "Status")
data, mappings = encode_categorical_columns(raw)

# 2. Split into Training (80%) and Testing (20%)
# We use random_state=42 to ensure the split is the same every time
input_train, input_test, output_train, output_test = train_test_split(data, expected, test_size=0.8, random_state=42)

# 3. Initialize the Tree
# 'max_depth' prevents the tree from becoming a giant, over-complicated mess
model = DecisionTreeClassifier(max_depth=3)

# 4. Train (Fit) the model
model.fit(input_train, output_train)

# 5. Predict and Evaluate
predictions = model.predict(input_test)
accuracy = accuracy_score(output_test, predictions)

print(f"Model Accuracy: {accuracy * 100:.2f}%")


# --- Interactive Prediction ---
# Ask user for input values for each feature column
user_input = {}
for col in data.columns:
    # Get mapping if column was encoded
    if col in mappings:
        options = list(mappings[col].values())
        prompt = f"Enter value for '{col}' (options: {options}): "
        val = input(f"{prompt}")
        # Convert string to code
        try:
            code = options.index(val)
        except ValueError:
            print(f"Invalid value for {col}. Using first option.")
            code = 0
        user_input[col] = code
    else:
        val = input(f"Enter value for '{col}': ")
        # Try to convert to float or int
        try:
            val = float(val)
        except ValueError:
            pass
        user_input[col] = val

# Convert to DataFrame
user_df = pd.DataFrame([user_input])

# Predict probability
probs = model.predict_proba(user_df)

# Show probabilities for each class
for i, class_label in enumerate(model.classes_):
    print(f"Probability of '{class_label}': {probs[0][i]*100:.2f}%")
# Out:
# Model Accuracy: 65.84%
# Invalid value for Site. Using first option.
# Invalid value for TumorType. Using first option.
# Invalid value for SampleType. Using first option.
# Invalid value for Race. Using first option.
# Invalid value for Sex. Using first option.
# Invalid value for Histology. Using first option.
# Probability of 'Alive': 50.00%
# Probability of 'Dead': 50.00%
# Probability of 'Unknown': 0.00%

# %%
import pandas as pd
import sys

import itertools

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

import joblib

import pandas as pd

def load_csv_for_decision_tree(csv_path, target_column):
    """
    Loads a CSV file and returns features (X) and target (y) for scikit-learn.

    Args:
        csv_path (str): Path to the CSV file.
        target_column (str): Name of the target column.

    Returns:
        X (pd.DataFrame): Features.
        y (pd.Series): Target variable.
    """

    df = pd.read_csv(csv_path).drop(columns=["patientID"])
    X = df.drop(columns=[target_column])
    y = df[target_column]
    return X, y

def encode_categorical_columns(df):
    """
    Encodes all string (object or category) columns in the DataFrame with unique integer codes.
    Returns a new DataFrame with encoded columns and a dictionary mapping columns to their value mappings.
    """
    encoded_df = df.copy()
    mappings = {}
    for col in encoded_df.select_dtypes(include=['object', 'category']).columns:
        encoded_df[col], uniques = pd.factorize(encoded_df[col])
        mappings[col] = dict(enumerate(uniques))
    return encoded_df, mappings

[raw, expected] = load_csv_for_decision_tree("MP2PRTWT.clinical.csv", "Status")
data, mappings = encode_categorical_columns(raw)

# 2. Split into Training (80%) and Testing (20%)
# We use random_state=42 to ensure the split is the same every time
input_train, input_test, output_train, output_test = train_test_split(data, expected, test_size=0.8, random_state=42)

# 3. Initialize the Tree
# 'max_depth' prevents the tree from becoming a giant, over-complicated mess
model = DecisionTreeClassifier(max_depth=3)

# 4. Train (Fit) the model
model.fit(input_train, output_train)

# 5. Predict and Evaluate
predictions = model.predict(input_test)
accuracy = accuracy_score(output_test, predictions)

print(f"Model Accuracy: {accuracy * 100:.2f}%")
# Out:
# Model Accuracy: 66.46%
# ('Site', 'TumorType', 'SampleType', 'Race', 'Sex', 'Histology')
# ('Site', 'TumorType', 'SampleType', 'Race', 'Histology', 'Sex')
# ('Site', 'TumorType', 'SampleType', 'Sex', 'Race', 'Histology')
# ('Site', 'TumorType', 'SampleType', 'Sex', 'Histology', 'Race')
# ('Site', 'TumorType', 'SampleType', 'Histology', 'Race', 'Sex')
# ('Site', 'TumorType', 'SampleType', 'Histology', 'Sex', 'Race')
# ('Site', 'TumorType', 'Race', 'SampleType', 'Sex', 'Histology')
# ('Site', 'TumorType', 'Race', 'SampleType', 'Histology', 'Sex')
# ('Site', 'TumorType', 'Race', 'Sex', 'SampleType', 'Histology')
# ('Site', 'TumorType', 'Race', 'Sex', 'Histology', 'SampleType')
# ('Site', 'TumorType', 'Race', 'Histology', 'SampleType', 'Sex')
# ('Site', 'TumorType', 'Race', 'Histology', 'Sex', 'SampleType')
# ('Site', 'TumorType', 'Sex', 'SampleType', 'Race', 'Histology')
# ('Site', 'TumorType', 'Sex', 'SampleType', 'Histology', 'Race')
# ('Site', 'TumorType', 'Sex', 'Race', 'SampleType', 'Histology')
# ('Site', 'TumorType', 'Sex', 'Race', 'Histology', 'SampleType')
# ('Site', 'TumorType', 'Sex', 'Histology', 'SampleType', 'Race')
# ('Site', 'TumorType', 'Sex', 'Histology', 'Race', 'SampleType')
# ('Site', 'TumorType', 'Histology', 'SampleType', 'Race', 'Sex')
# ('Site', 'TumorType', 'Histology', 'SampleType', 'Sex', 'Race')
# ('Site', 'TumorType', 'Histology', 'Race', 'SampleType', 'Sex')
# ('Site', 'TumorType', 'Histology', 'Race', 'Sex', 'SampleType')
# ('Site', 'TumorType', 'Histology', 'Sex', 'SampleType', 'Race')
# ('Site', 'TumorType', 'Histology', 'Sex', 'Race', 'SampleType')
# ('Site', 'SampleType', 'TumorType', 'Race', 'Sex', 'Histology')
# ('Site', 'SampleType', 'TumorType', 'Race', 'Histology', 'Sex')
# ('Site', 'SampleType', 'TumorType', 'Sex', 'Race', 'Histology')
# ('Site', 'SampleType', 'TumorType', 'Sex', 'Histology', 'Race')
# ('Site', 'SampleType', 'TumorType', 'Histology', 'Race', 'Sex')
# ('Site', 'SampleType', 'TumorType', 'Histology', 'Sex', 'Race')
# ('Site', 'SampleType', 'Race', 'TumorType', 'Sex', 'Histology')
# ('Site', 'SampleType', 'Race', 'TumorType', 'Histology', 'Sex')
# ('Site', 'SampleType', 'Race', 'Sex', 'TumorType', 'Histology')
# ('Site', 'SampleType', 'Race', 'Sex', 'Histology', 'TumorType')
# ('Site', 'SampleType', 'Race', 'Histology', 'TumorType', 'Sex')
# ('Site', 'SampleType', 'Race', 'Histology', 'Sex', 'TumorType')
# ('Site', 'SampleType', 'Sex', 'TumorType', 'Race', 'Histology')
# ('Site', 'SampleType', 'Sex', 'TumorType', 'Histology', 'Race')
# ('Site', 'SampleType', 'Sex', 'Race', 'TumorType', 'Histology')
# ('Site', 'SampleType', 'Sex', 'Race', 'Histology', 'TumorType')
# ('Site', 'SampleType', 'Sex', 'Histology', 'TumorType', 'Race')
# ('Site', 'SampleType', 'Sex', 'Histology', 'Race', 'TumorType')
# ('Site', 'SampleType', 'Histology', 'TumorType', 'Race', 'Sex')
# ('Site', 'SampleType', 'Histology', 'TumorType', 'Sex', 'Race')
# ('Site', 'SampleType', 'Histology', 'Race', 'TumorType', 'Sex')
# ('Site', 'SampleType', 'Histology', 'Race', 'Sex', 'TumorType')
# ('Site', 'SampleType', 'Histology', 'Sex', 'TumorType', 'Race')
# ('Site', 'SampleType', 'Histology', 'Sex', 'Race', 'TumorType')
# ('Site', 'Race', 'TumorType', 'SampleType', 'Sex', 'Histology')
# ('Site', 'Race', 'TumorType', 'SampleType', 'Histology', 'Sex')
# ('Site', 'Race', 'TumorType', 'Sex', 'SampleType', 'Histology')
# ('Site', 'Race', 'TumorType', 'Sex', 'Histology', 'SampleType')
# ('Site', 'Race', 'TumorType', 'Histology', 'SampleType', 'Sex')
# ('Site', 'Race', 'TumorType', 'Histology', 'Sex', 'SampleType')
# ('Site', 'Race', 'SampleType', 'TumorType', 'Sex', 'Histology')
# ('Site', 'Race', 'SampleType', 'TumorType', 'Histology', 'Sex')
# ('Site', 'Race', 'SampleType', 'Sex', 'TumorType', 'Histology')
# ('Site', 'Race', 'SampleType', 'Sex', 'Histology', 'TumorType')
# ('Site', 'Race', 'SampleType', 'Histology', 'TumorType', 'Sex')
# ('Site', 'Race', 'SampleType', 'Histology', 'Sex', 'TumorType')
# ('Site', 'Race', 'Sex', 'TumorType', 'SampleType', 'Histology')
# ('Site', 'Race', 'Sex', 'TumorType', 'Histology', 'SampleType')
# ('Site', 'Race', 'Sex', 'SampleType', 'TumorType', 'Histology')
# ('Site', 'Race', 'Sex', 'SampleType', 'Histology', 'TumorType')
# ('Site', 'Race', 'Sex', 'Histology', 'TumorType', 'SampleType')
# ('Site', 'Race', 'Sex', 'Histology', 'SampleType', 'TumorType')
# ('Site', 'Race', 'Histology', 'TumorType', 'SampleType', 'Sex')
# ('Site', 'Race', 'Histology', 'TumorType', 'Sex', 'SampleType')
# ('Site', 'Race', 'Histology', 'SampleType', 'TumorType', 'Sex')
# ('Site', 'Race', 'Histology', 'SampleType', 'Sex', 'TumorType')
# ('Site', 'Race', 'Histology', 'Sex', 'TumorType', 'SampleType')
# ('Site', 'Race', 'Histology', 'Sex', 'SampleType', 'TumorType')
# ('Site', 'Sex', 'TumorType', 'SampleType', 'Race', 'Histology')
# ('Site', 'Sex', 'TumorType', 'SampleType', 'Histology', 'Race')
# ('Site', 'Sex', 'TumorType', 'Race', 'SampleType', 'Histology')
# ('Site', 'Sex', 'TumorType', 'Race', 'Histology', 'SampleType')
# ('Site', 'Sex', 'TumorType', 'Histology', 'SampleType', 'Race')
# ('Site', 'Sex', 'TumorType', 'Histology', 'Race', 'SampleType')
# ('Site', 'Sex', 'SampleType', 'TumorType', 'Race', 'Histology')
# ('Site', 'Sex', 'SampleType', 'TumorType', 'Histology', 'Race')
# ('Site', 'Sex', 'SampleType', 'Race', 'TumorType', 'Histology')
# ('Site', 'Sex', 'SampleType', 'Race', 'Histology', 'TumorType')
# ('Site', 'Sex', 'SampleType', 'Histology', 'TumorType', 'Race')
# ('Site', 'Sex', 'SampleType', 'Histology', 'Race', 'TumorType')
# ('Site', 'Sex', 'Race', 'TumorType', 'SampleType', 'Histology')
# ('Site', 'Sex', 'Race', 'TumorType', 'Histology', 'SampleType')
# ('Site', 'Sex', 'Race', 'SampleType', 'TumorType', 'Histology')
# ('Site', 'Sex', 'Race', 'SampleType', 'Histology', 'TumorType')
# ('Site', 'Sex', 'Race', 'Histology', 'TumorType', 'SampleType')
# ('Site', 'Sex', 'Race', 'Histology', 'SampleType', 'TumorType')
# ('Site', 'Sex', 'Histology', 'TumorType', 'SampleType', 'Race')
# ('Site', 'Sex', 'Histology', 'TumorType', 'Race', 'SampleType')
# ('Site', 'Sex', 'Histology', 'SampleType', 'TumorType', 'Race')
# ('Site', 'Sex', 'Histology', 'SampleType', 'Race', 'TumorType')
# ('Site', 'Sex', 'Histology', 'Race', 'TumorType', 'SampleType')
# ('Site', 'Sex', 'Histology', 'Race', 'SampleType', 'TumorType')
# ('Site', 'Histology', 'TumorType', 'SampleType', 'Race', 'Sex')
# ('Site', 'Histology', 'TumorType', 'SampleType', 'Sex', 'Race')
# ('Site', 'Histology', 'TumorType', 'Race', 'SampleType', 'Sex')
# ('Site', 'Histology', 'TumorType', 'Race', 'Sex', 'SampleType')
# ('Site', 'Histology', 'TumorType', 'Sex', 'SampleType', 'Race')
# ('Site', 'Histology', 'TumorType', 'Sex', 'Race', 'SampleType')
# ('Site', 'Histology', 'SampleType', 'TumorType', 'Race', 'Sex')
# ('Site', 'Histology', 'SampleType', 'TumorType', 'Sex', 'Race')
# ('Site', 'Histology', 'SampleType', 'Race', 'TumorType', 'Sex')
# ('Site', 'Histology', 'SampleType', 'Race', 'Sex', 'TumorType')
# ('Site', 'Histology', 'SampleType', 'Sex', 'TumorType', 'Race')
# ('Site', 'Histology', 'SampleType', 'Sex', 'Race', 'TumorType')
# ('Site', 'Histology', 'Race', 'TumorType', 'SampleType', 'Sex')
# ('Site', 'Histology', 'Race', 'TumorType', 'Sex', 'SampleType')
# ('Site', 'Histology', 'Race', 'SampleType', 'TumorType', 'Sex')
# ('Site', 'Histology', 'Race', 'SampleType', 'Sex', 'TumorType')
# ('Site', 'Histology', 'Race', 'Sex', 'TumorType', 'SampleType')
# ('Site', 'Histology', 'Race', 'Sex', 'SampleType', 'TumorType')
# ('Site', 'Histology', 'Sex', 'TumorType', 'SampleType', 'Race')
# ('Site', 'Histology', 'Sex', 'TumorType', 'Race', 'SampleType')
# ('Site', 'Histology', 'Sex', 'SampleType', 'TumorType', 'Race')
# ('Site', 'Histology', 'Sex', 'SampleType', 'Race', 'TumorType')
# ('Site', 'Histology', 'Sex', 'Race', 'TumorType', 'SampleType')
# ('Site', 'Histology', 'Sex', 'Race', 'SampleType', 'TumorType')
# ('TumorType', 'Site', 'SampleType', 'Race', 'Sex', 'Histology')
# ('TumorType', 'Site', 'SampleType', 'Race', 'Histology', 'Sex')
# ('TumorType', 'Site', 'SampleType', 'Sex', 'Race', 'Histology')
# ('TumorType', 'Site', 'SampleType', 'Sex', 'Histology', 'Race')
# ('TumorType', 'Site', 'SampleType', 'Histology', 'Race', 'Sex')
# ('TumorType', 'Site', 'SampleType', 'Histology', 'Sex', 'Race')
# ('TumorType', 'Site', 'Race', 'SampleType', 'Sex', 'Histology')
# ('TumorType', 'Site', 'Race', 'SampleType', 'Histology', 'Sex')
# ('TumorType', 'Site', 'Race', 'Sex', 'SampleType', 'Histology')
# ('TumorType', 'Site', 'Race', 'Sex', 'Histology', 'SampleType')
# ('TumorType', 'Site', 'Race', 'Histology', 'SampleType', 'Sex')
# ('TumorType', 'Site', 'Race', 'Histology', 'Sex', 'SampleType')
# ('TumorType', 'Site', 'Sex', 'SampleType', 'Race', 'Histology')
# ('TumorType', 'Site', 'Sex', 'SampleType', 'Histology', 'Race')
# ('TumorType', 'Site', 'Sex', 'Race', 'SampleType', 'Histology')
# ('TumorType', 'Site', 'Sex', 'Race', 'Histology', 'SampleType')
# ('TumorType', 'Site', 'Sex', 'Histology', 'SampleType', 'Race')
# ('TumorType', 'Site', 'Sex', 'Histology', 'Race', 'SampleType')
# ('TumorType', 'Site', 'Histology', 'SampleType', 'Race', 'Sex')
# ('TumorType', 'Site', 'Histology', 'SampleType', 'Sex', 'Race')
# ('TumorType', 'Site', 'Histology', 'Race', 'SampleType', 'Sex')
# ('TumorType', 'Site', 'Histology', 'Race', 'Sex', 'SampleType')
# ('TumorType', 'Site', 'Histology', 'Sex', 'SampleType', 'Race')
# ('TumorType', 'Site', 'Histology', 'Sex', 'Race', 'SampleType')
# ('TumorType', 'SampleType', 'Site', 'Race', 'Sex', 'Histology')
# ('TumorType', 'SampleType', 'Site', 'Race', 'Histology', 'Sex')
# ('TumorType', 'SampleType', 'Site', 'Sex', 'Race', 'Histology')
# ('TumorType', 'SampleType', 'Site', 'Sex', 'Histology', 'Race')
# ('TumorType', 'SampleType', 'Site', 'Histology', 'Race', 'Sex')
# ('TumorType', 'SampleType', 'Site', 'Histology', 'Sex', 'Race')
# ('TumorType', 'SampleType', 'Race', 'Site', 'Sex', 'Histology')
# ('TumorType', 'SampleType', 'Race', 'Site', 'Histology', 'Sex')
# ('TumorType', 'SampleType', 'Race', 'Sex', 'Site', 'Histology')
# ('TumorType', 'SampleType', 'Race', 'Sex', 'Histology', 'Site')
# ('TumorType', 'SampleType', 'Race', 'Histology', 'Site', 'Sex')
# ('TumorType', 'SampleType', 'Race', 'Histology', 'Sex', 'Site')
# ('TumorType', 'SampleType', 'Sex', 'Site', 'Race', 'Histology')
# ('TumorType', 'SampleType', 'Sex', 'Site', 'Histology', 'Race')
# ('TumorType', 'SampleType', 'Sex', 'Race', 'Site', 'Histology')
# ('TumorType', 'SampleType', 'Sex', 'Race', 'Histology', 'Site')
# ('TumorType', 'SampleType', 'Sex', 'Histology', 'Site', 'Race')
# ('TumorType', 'SampleType', 'Sex', 'Histology', 'Race', 'Site')
# ('TumorType', 'SampleType', 'Histology', 'Site', 'Race', 'Sex')
# ('TumorType', 'SampleType', 'Histology', 'Site', 'Sex', 'Race')
# ('TumorType', 'SampleType', 'Histology', 'Race', 'Site', 'Sex')
# ('TumorType', 'SampleType', 'Histology', 'Race', 'Sex', 'Site')
# ('TumorType', 'SampleType', 'Histology', 'Sex', 'Site', 'Race')
# ('TumorType', 'SampleType', 'Histology', 'Sex', 'Race', 'Site')
# ('TumorType', 'Race', 'Site', 'SampleType', 'Sex', 'Histology')
# ('TumorType', 'Race', 'Site', 'SampleType', 'Histology', 'Sex')
# ('TumorType', 'Race', 'Site', 'Sex', 'SampleType', 'Histology')
# ('TumorType', 'Race', 'Site', 'Sex', 'Histology', 'SampleType')
# ('TumorType', 'Race', 'Site', 'Histology', 'SampleType', 'Sex')
# ('TumorType', 'Race', 'Site', 'Histology', 'Sex', 'SampleType')
# ('TumorType', 'Race', 'SampleType', 'Site', 'Sex', 'Histology')
# ('TumorType', 'Race', 'SampleType', 'Site', 'Histology', 'Sex')
# ('TumorType', 'Race', 'SampleType', 'Sex', 'Site', 'Histology')
# ('TumorType', 'Race', 'SampleType', 'Sex', 'Histology', 'Site')
# ('TumorType', 'Race', 'SampleType', 'Histology', 'Site', 'Sex')
# ('TumorType', 'Race', 'SampleType', 'Histology', 'Sex', 'Site')
# ('TumorType', 'Race', 'Sex', 'Site', 'SampleType', 'Histology')
# ('TumorType', 'Race', 'Sex', 'Site', 'Histology', 'SampleType')
# ('TumorType', 'Race', 'Sex', 'SampleType', 'Site', 'Histology')
# ('TumorType', 'Race', 'Sex', 'SampleType', 'Histology', 'Site')
# ('TumorType', 'Race', 'Sex', 'Histology', 'Site', 'SampleType')
# ('TumorType', 'Race', 'Sex', 'Histology', 'SampleType', 'Site')
# ('TumorType', 'Race', 'Histology', 'Site', 'SampleType', 'Sex')
# ('TumorType', 'Race', 'Histology', 'Site', 'Sex', 'SampleType')
# ('TumorType', 'Race', 'Histology', 'SampleType', 'Site', 'Sex')
# ('TumorType', 'Race', 'Histology', 'SampleType', 'Sex', 'Site')
# ('TumorType', 'Race', 'Histology', 'Sex', 'Site', 'SampleType')
# ('TumorType', 'Race', 'Histology', 'Sex', 'SampleType', 'Site')
# ('TumorType', 'Sex', 'Site', 'SampleType', 'Race', 'Histology')
# ('TumorType', 'Sex', 'Site', 'SampleType', 'Histology', 'Race')
# ('TumorType', 'Sex', 'Site', 'Race', 'SampleType', 'Histology')
# ('TumorType', 'Sex', 'Site', 'Race', 'Histology', 'SampleType')
# ('TumorType', 'Sex', 'Site', 'Histology', 'SampleType', 'Race')
# ('TumorType', 'Sex', 'Site', 'Histology', 'Race', 'SampleType')
# ('TumorType', 'Sex', 'SampleType', 'Site', 'Race', 'Histology')
# ('TumorType', 'Sex', 'SampleType', 'Site', 'Histology', 'Race')
# ('TumorType', 'Sex', 'SampleType', 'Race', 'Site', 'Histology')
# ('TumorType', 'Sex', 'SampleType', 'Race', 'Histology', 'Site')
# ('TumorType', 'Sex', 'SampleType', 'Histology', 'Site', 'Race')
# ('TumorType', 'Sex', 'SampleType', 'Histology', 'Race', 'Site')
# ('TumorType', 'Sex', 'Race', 'Site', 'SampleType', 'Histology')
# ('TumorType', 'Sex', 'Race', 'Site', 'Histology', 'SampleType')
# ('TumorType', 'Sex', 'Race', 'SampleType', 'Site', 'Histology')
# ('TumorType', 'Sex', 'Race', 'SampleType', 'Histology', 'Site')
# ('TumorType', 'Sex', 'Race', 'Histology', 'Site', 'SampleType')
# ('TumorType', 'Sex', 'Race', 'Histology', 'SampleType', 'Site')
# ('TumorType', 'Sex', 'Histology', 'Site', 'SampleType', 'Race')
# ('TumorType', 'Sex', 'Histology', 'Site', 'Race', 'SampleType')
# ('TumorType', 'Sex', 'Histology', 'SampleType', 'Site', 'Race')
# ('TumorType', 'Sex', 'Histology', 'SampleType', 'Race', 'Site')
# ('TumorType', 'Sex', 'Histology', 'Race', 'Site', 'SampleType')
# ('TumorType', 'Sex', 'Histology', 'Race', 'SampleType', 'Site')
# ('TumorType', 'Histology', 'Site', 'SampleType', 'Race', 'Sex')
# ('TumorType', 'Histology', 'Site', 'SampleType', 'Sex', 'Race')
# ('TumorType', 'Histology', 'Site', 'Race', 'SampleType', 'Sex')
# ('TumorType', 'Histology', 'Site', 'Race', 'Sex', 'SampleType')
# ('TumorType', 'Histology', 'Site', 'Sex', 'SampleType', 'Race')
# ('TumorType', 'Histology', 'Site', 'Sex', 'Race', 'SampleType')
# ('TumorType', 'Histology', 'SampleType', 'Site', 'Race', 'Sex')
# ('TumorType', 'Histology', 'SampleType', 'Site', 'Sex', 'Race')
# ('TumorType', 'Histology', 'SampleType', 'Race', 'Site', 'Sex')
# ('TumorType', 'Histology', 'SampleType', 'Race', 'Sex', 'Site')
# ('TumorType', 'Histology', 'SampleType', 'Sex', 'Site', 'Race')
# ('TumorType', 'Histology', 'SampleType', 'Sex', 'Race', 'Site')
# ('TumorType', 'Histology', 'Race', 'Site', 'SampleType', 'Sex')
# ('TumorType', 'Histology', 'Race', 'Site', 'Sex', 'SampleType')
# ('TumorType', 'Histology', 'Race', 'SampleType', 'Site', 'Sex')
# ('TumorType', 'Histology', 'Race', 'SampleType', 'Sex', 'Site')
# ('TumorType', 'Histology', 'Race', 'Sex', 'Site', 'SampleType')
# ('TumorType', 'Histology', 'Race', 'Sex', 'SampleType', 'Site')
# ('TumorType', 'Histology', 'Sex', 'Site', 'SampleType', 'Race')
# ('TumorType', 'Histology', 'Sex', 'Site', 'Race', 'SampleType')
# ('TumorType', 'Histology', 'Sex', 'SampleType', 'Site', 'Race')
# ('TumorType', 'Histology', 'Sex', 'SampleType', 'Race', 'Site')
# ('TumorType', 'Histology', 'Sex', 'Race', 'Site', 'SampleType')
# ('TumorType', 'Histology', 'Sex', 'Race', 'SampleType', 'Site')
# ('SampleType', 'Site', 'TumorType', 'Race', 'Sex', 'Histology')
# ('SampleType', 'Site', 'TumorType', 'Race', 'Histology', 'Sex')
# ('SampleType', 'Site', 'TumorType', 'Sex', 'Race', 'Histology')
# ('SampleType', 'Site', 'TumorType', 'Sex', 'Histology', 'Race')
# ('SampleType', 'Site', 'TumorType', 'Histology', 'Race', 'Sex')
# ('SampleType', 'Site', 'TumorType', 'Histology', 'Sex', 'Race')
# ('SampleType', 'Site', 'Race', 'TumorType', 'Sex', 'Histology')
# ('SampleType', 'Site', 'Race', 'TumorType', 'Histology', 'Sex')
# ('SampleType', 'Site', 'Race', 'Sex', 'TumorType', 'Histology')
# ('SampleType', 'Site', 'Race', 'Sex', 'Histology', 'TumorType')
# ('SampleType', 'Site', 'Race', 'Histology', 'TumorType', 'Sex')
# ('SampleType', 'Site', 'Race', 'Histology', 'Sex', 'TumorType')
# ('SampleType', 'Site', 'Sex', 'TumorType', 'Race', 'Histology')
# ('SampleType', 'Site', 'Sex', 'TumorType', 'Histology', 'Race')
# ('SampleType', 'Site', 'Sex', 'Race', 'TumorType', 'Histology')
# ('SampleType', 'Site', 'Sex', 'Race', 'Histology', 'TumorType')
# ('SampleType', 'Site', 'Sex', 'Histology', 'TumorType', 'Race')
# ('SampleType', 'Site', 'Sex', 'Histology', 'Race', 'TumorType')
# ('SampleType', 'Site', 'Histology', 'TumorType', 'Race', 'Sex')
# ('SampleType', 'Site', 'Histology', 'TumorType', 'Sex', 'Race')
# ('SampleType', 'Site', 'Histology', 'Race', 'TumorType', 'Sex')
# ('SampleType', 'Site', 'Histology', 'Race', 'Sex', 'TumorType')
# ('SampleType', 'Site', 'Histology', 'Sex', 'TumorType', 'Race')
# ('SampleType', 'Site', 'Histology', 'Sex', 'Race', 'TumorType')
# ('SampleType', 'TumorType', 'Site', 'Race', 'Sex', 'Histology')
# ('SampleType', 'TumorType', 'Site', 'Race', 'Histology', 'Sex')
# ('SampleType', 'TumorType', 'Site', 'Sex', 'Race', 'Histology')
# ('SampleType', 'TumorType', 'Site', 'Sex', 'Histology', 'Race')
# ('SampleType', 'TumorType', 'Site', 'Histology', 'Race', 'Sex')
# ('SampleType', 'TumorType', 'Site', 'Histology', 'Sex', 'Race')
# ('SampleType', 'TumorType', 'Race', 'Site', 'Sex', 'Histology')
# ('SampleType', 'TumorType', 'Race', 'Site', 'Histology', 'Sex')
# ('SampleType', 'TumorType', 'Race', 'Sex', 'Site', 'Histology')
# ('SampleType', 'TumorType', 'Race', 'Sex', 'Histology', 'Site')
# ('SampleType', 'TumorType', 'Race', 'Histology', 'Site', 'Sex')
# ('SampleType', 'TumorType', 'Race', 'Histology', 'Sex', 'Site')
# ('SampleType', 'TumorType', 'Sex', 'Site', 'Race', 'Histology')
# ('SampleType', 'TumorType', 'Sex', 'Site', 'Histology', 'Race')
# ('SampleType', 'TumorType', 'Sex', 'Race', 'Site', 'Histology')
# ('SampleType', 'TumorType', 'Sex', 'Race', 'Histology', 'Site')
# ('SampleType', 'TumorType', 'Sex', 'Histology', 'Site', 'Race')
# ('SampleType', 'TumorType', 'Sex', 'Histology', 'Race', 'Site')
# ('SampleType', 'TumorType', 'Histology', 'Site', 'Race', 'Sex')
# ('SampleType', 'TumorType', 'Histology', 'Site', 'Sex', 'Race')
# ('SampleType', 'TumorType', 'Histology', 'Race', 'Site', 'Sex')
# ('SampleType', 'TumorType', 'Histology', 'Race', 'Sex', 'Site')
# ('SampleType', 'TumorType', 'Histology', 'Sex', 'Site', 'Race')
# ('SampleType', 'TumorType', 'Histology', 'Sex', 'Race', 'Site')
# ('SampleType', 'Race', 'Site', 'TumorType', 'Sex', 'Histology')
# ('SampleType', 'Race', 'Site', 'TumorType', 'Histology', 'Sex')
# ('SampleType', 'Race', 'Site', 'Sex', 'TumorType', 'Histology')
# ('SampleType', 'Race', 'Site', 'Sex', 'Histology', 'TumorType')
# ('SampleType', 'Race', 'Site', 'Histology', 'TumorType', 'Sex')
# ('SampleType', 'Race', 'Site', 'Histology', 'Sex', 'TumorType')
# ('SampleType', 'Race', 'TumorType', 'Site', 'Sex', 'Histology')
# ('SampleType', 'Race', 'TumorType', 'Site', 'Histology', 'Sex')
# ('SampleType', 'Race', 'TumorType', 'Sex', 'Site', 'Histology')
# ('SampleType', 'Race', 'TumorType', 'Sex', 'Histology', 'Site')
# ('SampleType', 'Race', 'TumorType', 'Histology', 'Site', 'Sex')
# ('SampleType', 'Race', 'TumorType', 'Histology', 'Sex', 'Site')
# ('SampleType', 'Race', 'Sex', 'Site', 'TumorType', 'Histology')
# ('SampleType', 'Race', 'Sex', 'Site', 'Histology', 'TumorType')
# ('SampleType', 'Race', 'Sex', 'TumorType', 'Site', 'Histology')
# ('SampleType', 'Race', 'Sex', 'TumorType', 'Histology', 'Site')
# ('SampleType', 'Race', 'Sex', 'Histology', 'Site', 'TumorType')
# ('SampleType', 'Race', 'Sex', 'Histology', 'TumorType', 'Site')
# ('SampleType', 'Race', 'Histology', 'Site', 'TumorType', 'Sex')
# ('SampleType', 'Race', 'Histology', 'Site', 'Sex', 'TumorType')
# ('SampleType', 'Race', 'Histology', 'TumorType', 'Site', 'Sex')
# ('SampleType', 'Race', 'Histology', 'TumorType', 'Sex', 'Site')
# ('SampleType', 'Race', 'Histology', 'Sex', 'Site', 'TumorType')
# ('SampleType', 'Race', 'Histology', 'Sex', 'TumorType', 'Site')
# ('SampleType', 'Sex', 'Site', 'TumorType', 'Race', 'Histology')
# ('SampleType', 'Sex', 'Site', 'TumorType', 'Histology', 'Race')
# ('SampleType', 'Sex', 'Site', 'Race', 'TumorType', 'Histology')
# ('SampleType', 'Sex', 'Site', 'Race', 'Histology', 'TumorType')
# ('SampleType', 'Sex', 'Site', 'Histology', 'TumorType', 'Race')
# ('SampleType', 'Sex', 'Site', 'Histology', 'Race', 'TumorType')
# ('SampleType', 'Sex', 'TumorType', 'Site', 'Race', 'Histology')
# ('SampleType', 'Sex', 'TumorType', 'Site', 'Histology', 'Race')
# ('SampleType', 'Sex', 'TumorType', 'Race', 'Site', 'Histology')
# ('SampleType', 'Sex', 'TumorType', 'Race', 'Histology', 'Site')
# ('SampleType', 'Sex', 'TumorType', 'Histology', 'Site', 'Race')
# ('SampleType', 'Sex', 'TumorType', 'Histology', 'Race', 'Site')
# ('SampleType', 'Sex', 'Race', 'Site', 'TumorType', 'Histology')
# ('SampleType', 'Sex', 'Race', 'Site', 'Histology', 'TumorType')
# ('SampleType', 'Sex', 'Race', 'TumorType', 'Site', 'Histology')
# ('SampleType', 'Sex', 'Race', 'TumorType', 'Histology', 'Site')
# ('SampleType', 'Sex', 'Race', 'Histology', 'Site', 'TumorType')
# ('SampleType', 'Sex', 'Race', 'Histology', 'TumorType', 'Site')
# ('SampleType', 'Sex', 'Histology', 'Site', 'TumorType', 'Race')
# ('SampleType', 'Sex', 'Histology', 'Site', 'Race', 'TumorType')
# ('SampleType', 'Sex', 'Histology', 'TumorType', 'Site', 'Race')
# ('SampleType', 'Sex', 'Histology', 'TumorType', 'Race', 'Site')
# ('SampleType', 'Sex', 'Histology', 'Race', 'Site', 'TumorType')
# ('SampleType', 'Sex', 'Histology', 'Race', 'TumorType', 'Site')
# ('SampleType', 'Histology', 'Site', 'TumorType', 'Race', 'Sex')
# ('SampleType', 'Histology', 'Site', 'TumorType', 'Sex', 'Race')
# ('SampleType', 'Histology', 'Site', 'Race', 'TumorType', 'Sex')
# ('SampleType', 'Histology', 'Site', 'Race', 'Sex', 'TumorType')
# ('SampleType', 'Histology', 'Site', 'Sex', 'TumorType', 'Race')
# ('SampleType', 'Histology', 'Site', 'Sex', 'Race', 'TumorType')
# ('SampleType', 'Histology', 'TumorType', 'Site', 'Race', 'Sex')
# ('SampleType', 'Histology', 'TumorType', 'Site', 'Sex', 'Race')
# ('SampleType', 'Histology', 'TumorType', 'Race', 'Site', 'Sex')
# ('SampleType', 'Histology', 'TumorType', 'Race', 'Sex', 'Site')
# ('SampleType', 'Histology', 'TumorType', 'Sex', 'Site', 'Race')
# ('SampleType', 'Histology', 'TumorType', 'Sex', 'Race', 'Site')
# ('SampleType', 'Histology', 'Race', 'Site', 'TumorType', 'Sex')
# ('SampleType', 'Histology', 'Race', 'Site', 'Sex', 'TumorType')
# ('SampleType', 'Histology', 'Race', 'TumorType', 'Site', 'Sex')
# ('SampleType', 'Histology', 'Race', 'TumorType', 'Sex', 'Site')
# ('SampleType', 'Histology', 'Race', 'Sex', 'Site', 'TumorType')
# ('SampleType', 'Histology', 'Race', 'Sex', 'TumorType', 'Site')
# ('SampleType', 'Histology', 'Sex', 'Site', 'TumorType', 'Race')
# ('SampleType', 'Histology', 'Sex', 'Site', 'Race', 'TumorType')
# ('SampleType', 'Histology', 'Sex', 'TumorType', 'Site', 'Race')
# ('SampleType', 'Histology', 'Sex', 'TumorType', 'Race', 'Site')
# ('SampleType', 'Histology', 'Sex', 'Race', 'Site', 'TumorType')
# ('SampleType', 'Histology', 'Sex', 'Race', 'TumorType', 'Site')
# ('Race', 'Site', 'TumorType', 'SampleType', 'Sex', 'Histology')
# ('Race', 'Site', 'TumorType', 'SampleType', 'Histology', 'Sex')
# ('Race', 'Site', 'TumorType', 'Sex', 'SampleType', 'Histology')
# ('Race', 'Site', 'TumorType', 'Sex', 'Histology', 'SampleType')
# ('Race', 'Site', 'TumorType', 'Histology', 'SampleType', 'Sex')
# ('Race', 'Site', 'TumorType', 'Histology', 'Sex', 'SampleType')
# ('Race', 'Site', 'SampleType', 'TumorType', 'Sex', 'Histology')
# ('Race', 'Site', 'SampleType', 'TumorType', 'Histology', 'Sex')
# ('Race', 'Site', 'SampleType', 'Sex', 'TumorType', 'Histology')
# ('Race', 'Site', 'SampleType', 'Sex', 'Histology', 'TumorType')
# ('Race', 'Site', 'SampleType', 'Histology', 'TumorType', 'Sex')
# ('Race', 'Site', 'SampleType', 'Histology', 'Sex', 'TumorType')
# ('Race', 'Site', 'Sex', 'TumorType', 'SampleType', 'Histology')
# ('Race', 'Site', 'Sex', 'TumorType', 'Histology', 'SampleType')
# ('Race', 'Site', 'Sex', 'SampleType', 'TumorType', 'Histology')
# ('Race', 'Site', 'Sex', 'SampleType', 'Histology', 'TumorType')
# ('Race', 'Site', 'Sex', 'Histology', 'TumorType', 'SampleType')
# ('Race', 'Site', 'Sex', 'Histology', 'SampleType', 'TumorType')
# ('Race', 'Site', 'Histology', 'TumorType', 'SampleType', 'Sex')
# ('Race', 'Site', 'Histology', 'TumorType', 'Sex', 'SampleType')
# ('Race', 'Site', 'Histology', 'SampleType', 'TumorType', 'Sex')
# ('Race', 'Site', 'Histology', 'SampleType', 'Sex', 'TumorType')
# ('Race', 'Site', 'Histology', 'Sex', 'TumorType', 'SampleType')
# ('Race', 'Site', 'Histology', 'Sex', 'SampleType', 'TumorType')
# ('Race', 'TumorType', 'Site', 'SampleType', 'Sex', 'Histology')
# ('Race', 'TumorType', 'Site', 'SampleType', 'Histology', 'Sex')
# ('Race', 'TumorType', 'Site', 'Sex', 'SampleType', 'Histology')
# ('Race', 'TumorType', 'Site', 'Sex', 'Histology', 'SampleType')
# ('Race', 'TumorType', 'Site', 'Histology', 'SampleType', 'Sex')
# ('Race', 'TumorType', 'Site', 'Histology', 'Sex', 'SampleType')
# ('Race', 'TumorType', 'SampleType', 'Site', 'Sex', 'Histology')
# ('Race', 'TumorType', 'SampleType', 'Site', 'Histology', 'Sex')
# ('Race', 'TumorType', 'SampleType', 'Sex', 'Site', 'Histology')
# ('Race', 'TumorType', 'SampleType', 'Sex', 'Histology', 'Site')
# ('Race', 'TumorType', 'SampleType', 'Histology', 'Site', 'Sex')
# ('Race', 'TumorType', 'SampleType', 'Histology', 'Sex', 'Site')
# ('Race', 'TumorType', 'Sex', 'Site', 'SampleType', 'Histology')
# ('Race', 'TumorType', 'Sex', 'Site', 'Histology', 'SampleType')
# ('Race', 'TumorType', 'Sex', 'SampleType', 'Site', 'Histology')
# ('Race', 'TumorType', 'Sex', 'SampleType', 'Histology', 'Site')
# ('Race', 'TumorType', 'Sex', 'Histology', 'Site', 'SampleType')
# ('Race', 'TumorType', 'Sex', 'Histology', 'SampleType', 'Site')
# ('Race', 'TumorType', 'Histology', 'Site', 'SampleType', 'Sex')
# ('Race', 'TumorType', 'Histology', 'Site', 'Sex', 'SampleType')
# ('Race', 'TumorType', 'Histology', 'SampleType', 'Site', 'Sex')
# ('Race', 'TumorType', 'Histology', 'SampleType', 'Sex', 'Site')
# ('Race', 'TumorType', 'Histology', 'Sex', 'Site', 'SampleType')
# ('Race', 'TumorType', 'Histology', 'Sex', 'SampleType', 'Site')
# ('Race', 'SampleType', 'Site', 'TumorType', 'Sex', 'Histology')
# ('Race', 'SampleType', 'Site', 'TumorType', 'Histology', 'Sex')
# ('Race', 'SampleType', 'Site', 'Sex', 'TumorType', 'Histology')
# ('Race', 'SampleType', 'Site', 'Sex', 'Histology', 'TumorType')
# ('Race', 'SampleType', 'Site', 'Histology', 'TumorType', 'Sex')
# ('Race', 'SampleType', 'Site', 'Histology', 'Sex', 'TumorType')
# ('Race', 'SampleType', 'TumorType', 'Site', 'Sex', 'Histology')
# ('Race', 'SampleType', 'TumorType', 'Site', 'Histology', 'Sex')
# ('Race', 'SampleType', 'TumorType', 'Sex', 'Site', 'Histology')
# ('Race', 'SampleType', 'TumorType', 'Sex', 'Histology', 'Site')
# ('Race', 'SampleType', 'TumorType', 'Histology', 'Site', 'Sex')
# ('Race', 'SampleType', 'TumorType', 'Histology', 'Sex', 'Site')
# ('Race', 'SampleType', 'Sex', 'Site', 'TumorType', 'Histology')
# ('Race', 'SampleType', 'Sex', 'Site', 'Histology', 'TumorType')
# ('Race', 'SampleType', 'Sex', 'TumorType', 'Site', 'Histology')
# ('Race', 'SampleType', 'Sex', 'TumorType', 'Histology', 'Site')
# ('Race', 'SampleType', 'Sex', 'Histology', 'Site', 'TumorType')
# ('Race', 'SampleType', 'Sex', 'Histology', 'TumorType', 'Site')
# ('Race', 'SampleType', 'Histology', 'Site', 'TumorType', 'Sex')
# ('Race', 'SampleType', 'Histology', 'Site', 'Sex', 'TumorType')
# ('Race', 'SampleType', 'Histology', 'TumorType', 'Site', 'Sex')
# ('Race', 'SampleType', 'Histology', 'TumorType', 'Sex', 'Site')
# ('Race', 'SampleType', 'Histology', 'Sex', 'Site', 'TumorType')
# ('Race', 'SampleType', 'Histology', 'Sex', 'TumorType', 'Site')
# ('Race', 'Sex', 'Site', 'TumorType', 'SampleType', 'Histology')
# ('Race', 'Sex', 'Site', 'TumorType', 'Histology', 'SampleType')
# ('Race', 'Sex', 'Site', 'SampleType', 'TumorType', 'Histology')
# ('Race', 'Sex', 'Site', 'SampleType', 'Histology', 'TumorType')
# ('Race', 'Sex', 'Site', 'Histology', 'TumorType', 'SampleType')
# ('Race', 'Sex', 'Site', 'Histology', 'SampleType', 'TumorType')
# ('Race', 'Sex', 'TumorType', 'Site', 'SampleType', 'Histology')
# ('Race', 'Sex', 'TumorType', 'Site', 'Histology', 'SampleType')
# ('Race', 'Sex', 'TumorType', 'SampleType', 'Site', 'Histology')
# ('Race', 'Sex', 'TumorType', 'SampleType', 'Histology', 'Site')
# ('Race', 'Sex', 'TumorType', 'Histology', 'Site', 'SampleType')
# ('Race', 'Sex', 'TumorType', 'Histology', 'SampleType', 'Site')
# ('Race', 'Sex', 'SampleType', 'Site', 'TumorType', 'Histology')
# ('Race', 'Sex', 'SampleType', 'Site', 'Histology', 'TumorType')
# ('Race', 'Sex', 'SampleType', 'TumorType', 'Site', 'Histology')
# ('Race', 'Sex', 'SampleType', 'TumorType', 'Histology', 'Site')
# ('Race', 'Sex', 'SampleType', 'Histology', 'Site', 'TumorType')
# ('Race', 'Sex', 'SampleType', 'Histology', 'TumorType', 'Site')
# ('Race', 'Sex', 'Histology', 'Site', 'TumorType', 'SampleType')
# ('Race', 'Sex', 'Histology', 'Site', 'SampleType', 'TumorType')
# ('Race', 'Sex', 'Histology', 'TumorType', 'Site', 'SampleType')
# ('Race', 'Sex', 'Histology', 'TumorType', 'SampleType', 'Site')
# ('Race', 'Sex', 'Histology', 'SampleType', 'Site', 'TumorType')
# ('Race', 'Sex', 'Histology', 'SampleType', 'TumorType', 'Site')
# ('Race', 'Histology', 'Site', 'TumorType', 'SampleType', 'Sex')
# ('Race', 'Histology', 'Site', 'TumorType', 'Sex', 'SampleType')
# ('Race', 'Histology', 'Site', 'SampleType', 'TumorType', 'Sex')
# ('Race', 'Histology', 'Site', 'SampleType', 'Sex', 'TumorType')
# ('Race', 'Histology', 'Site', 'Sex', 'TumorType', 'SampleType')
# ('Race', 'Histology', 'Site', 'Sex', 'SampleType', 'TumorType')
# ('Race', 'Histology', 'TumorType', 'Site', 'SampleType', 'Sex')
# ('Race', 'Histology', 'TumorType', 'Site', 'Sex', 'SampleType')
# ('Race', 'Histology', 'TumorType', 'SampleType', 'Site', 'Sex')
# ('Race', 'Histology', 'TumorType', 'SampleType', 'Sex', 'Site')
# ('Race', 'Histology', 'TumorType', 'Sex', 'Site', 'SampleType')
# ('Race', 'Histology', 'TumorType', 'Sex', 'SampleType', 'Site')
# ('Race', 'Histology', 'SampleType', 'Site', 'TumorType', 'Sex')
# ('Race', 'Histology', 'SampleType', 'Site', 'Sex', 'TumorType')
# ('Race', 'Histology', 'SampleType', 'TumorType', 'Site', 'Sex')
# ('Race', 'Histology', 'SampleType', 'TumorType', 'Sex', 'Site')
# ('Race', 'Histology', 'SampleType', 'Sex', 'Site', 'TumorType')
# ('Race', 'Histology', 'SampleType', 'Sex', 'TumorType', 'Site')
# ('Race', 'Histology', 'Sex', 'Site', 'TumorType', 'SampleType')
# ('Race', 'Histology', 'Sex', 'Site', 'SampleType', 'TumorType')
# ('Race', 'Histology', 'Sex', 'TumorType', 'Site', 'SampleType')
# ('Race', 'Histology', 'Sex', 'TumorType', 'SampleType', 'Site')
# ('Race', 'Histology', 'Sex', 'SampleType', 'Site', 'TumorType')
# ('Race', 'Histology', 'Sex', 'SampleType', 'TumorType', 'Site')
# ('Sex', 'Site', 'TumorType', 'SampleType', 'Race', 'Histology')
# ('Sex', 'Site', 'TumorType', 'SampleType', 'Histology', 'Race')
# ('Sex', 'Site', 'TumorType', 'Race', 'SampleType', 'Histology')
# ('Sex', 'Site', 'TumorType', 'Race', 'Histology', 'SampleType')
# ('Sex', 'Site', 'TumorType', 'Histology', 'SampleType', 'Race')
# ('Sex', 'Site', 'TumorType', 'Histology', 'Race', 'SampleType')
# ('Sex', 'Site', 'SampleType', 'TumorType', 'Race', 'Histology')
# ('Sex', 'Site', 'SampleType', 'TumorType', 'Histology', 'Race')
# ('Sex', 'Site', 'SampleType', 'Race', 'TumorType', 'Histology')
# ('Sex', 'Site', 'SampleType', 'Race', 'Histology', 'TumorType')
# ('Sex', 'Site', 'SampleType', 'Histology', 'TumorType', 'Race')
# ('Sex', 'Site', 'SampleType', 'Histology', 'Race', 'TumorType')
# ('Sex', 'Site', 'Race', 'TumorType', 'SampleType', 'Histology')
# ('Sex', 'Site', 'Race', 'TumorType', 'Histology', 'SampleType')
# ('Sex', 'Site', 'Race', 'SampleType', 'TumorType', 'Histology')
# ('Sex', 'Site', 'Race', 'SampleType', 'Histology', 'TumorType')
# ('Sex', 'Site', 'Race', 'Histology', 'TumorType', 'SampleType')
# ('Sex', 'Site', 'Race', 'Histology', 'SampleType', 'TumorType')
# ('Sex', 'Site', 'Histology', 'TumorType', 'SampleType', 'Race')
# ('Sex', 'Site', 'Histology', 'TumorType', 'Race', 'SampleType')
# ('Sex', 'Site', 'Histology', 'SampleType', 'TumorType', 'Race')
# ('Sex', 'Site', 'Histology', 'SampleType', 'Race', 'TumorType')
# ('Sex', 'Site', 'Histology', 'Race', 'TumorType', 'SampleType')
# ('Sex', 'Site', 'Histology', 'Race', 'SampleType', 'TumorType')
# ('Sex', 'TumorType', 'Site', 'SampleType', 'Race', 'Histology')
# ('Sex', 'TumorType', 'Site', 'SampleType', 'Histology', 'Race')
# ('Sex', 'TumorType', 'Site', 'Race', 'SampleType', 'Histology')
# ('Sex', 'TumorType', 'Site', 'Race', 'Histology', 'SampleType')
# ('Sex', 'TumorType', 'Site', 'Histology', 'SampleType', 'Race')
# ('Sex', 'TumorType', 'Site', 'Histology', 'Race', 'SampleType')
# ('Sex', 'TumorType', 'SampleType', 'Site', 'Race', 'Histology')
# ('Sex', 'TumorType', 'SampleType', 'Site', 'Histology', 'Race')
# ('Sex', 'TumorType', 'SampleType', 'Race', 'Site', 'Histology')
# ('Sex', 'TumorType', 'SampleType', 'Race', 'Histology', 'Site')
# ('Sex', 'TumorType', 'SampleType', 'Histology', 'Site', 'Race')
# ('Sex', 'TumorType', 'SampleType', 'Histology', 'Race', 'Site')
# ('Sex', 'TumorType', 'Race', 'Site', 'SampleType', 'Histology')
# ('Sex', 'TumorType', 'Race', 'Site', 'Histology', 'SampleType')
# ('Sex', 'TumorType', 'Race', 'SampleType', 'Site', 'Histology')
# ('Sex', 'TumorType', 'Race', 'SampleType', 'Histology', 'Site')
# ('Sex', 'TumorType', 'Race', 'Histology', 'Site', 'SampleType')
# ('Sex', 'TumorType', 'Race', 'Histology', 'SampleType', 'Site')
# ('Sex', 'TumorType', 'Histology', 'Site', 'SampleType', 'Race')
# ('Sex', 'TumorType', 'Histology', 'Site', 'Race', 'SampleType')
# ('Sex', 'TumorType', 'Histology', 'SampleType', 'Site', 'Race')
# ('Sex', 'TumorType', 'Histology', 'SampleType', 'Race', 'Site')
# ('Sex', 'TumorType', 'Histology', 'Race', 'Site', 'SampleType')
# ('Sex', 'TumorType', 'Histology', 'Race', 'SampleType', 'Site')
# ('Sex', 'SampleType', 'Site', 'TumorType', 'Race', 'Histology')
# ('Sex', 'SampleType', 'Site', 'TumorType', 'Histology', 'Race')
# ('Sex', 'SampleType', 'Site', 'Race', 'TumorType', 'Histology')
# ('Sex', 'SampleType', 'Site', 'Race', 'Histology', 'TumorType')
# ('Sex', 'SampleType', 'Site', 'Histology', 'TumorType', 'Race')
# ('Sex', 'SampleType', 'Site', 'Histology', 'Race', 'TumorType')
# ('Sex', 'SampleType', 'TumorType', 'Site', 'Race', 'Histology')
# ('Sex', 'SampleType', 'TumorType', 'Site', 'Histology', 'Race')
# ('Sex', 'SampleType', 'TumorType', 'Race', 'Site', 'Histology')
# ('Sex', 'SampleType', 'TumorType', 'Race', 'Histology', 'Site')
# ('Sex', 'SampleType', 'TumorType', 'Histology', 'Site', 'Race')
# ('Sex', 'SampleType', 'TumorType', 'Histology', 'Race', 'Site')
# ('Sex', 'SampleType', 'Race', 'Site', 'TumorType', 'Histology')
# ('Sex', 'SampleType', 'Race', 'Site', 'Histology', 'TumorType')
# ('Sex', 'SampleType', 'Race', 'TumorType', 'Site', 'Histology')
# ('Sex', 'SampleType', 'Race', 'TumorType', 'Histology', 'Site')
# ('Sex', 'SampleType', 'Race', 'Histology', 'Site', 'TumorType')
# ('Sex', 'SampleType', 'Race', 'Histology', 'TumorType', 'Site')
# ('Sex', 'SampleType', 'Histology', 'Site', 'TumorType', 'Race')
# ('Sex', 'SampleType', 'Histology', 'Site', 'Race', 'TumorType')
# ('Sex', 'SampleType', 'Histology', 'TumorType', 'Site', 'Race')
# ('Sex', 'SampleType', 'Histology', 'TumorType', 'Race', 'Site')
# ('Sex', 'SampleType', 'Histology', 'Race', 'Site', 'TumorType')
# ('Sex', 'SampleType', 'Histology', 'Race', 'TumorType', 'Site')
# ('Sex', 'Race', 'Site', 'TumorType', 'SampleType', 'Histology')
# ('Sex', 'Race', 'Site', 'TumorType', 'Histology', 'SampleType')
# ('Sex', 'Race', 'Site', 'SampleType', 'TumorType', 'Histology')
# ('Sex', 'Race', 'Site', 'SampleType', 'Histology', 'TumorType')
# ('Sex', 'Race', 'Site', 'Histology', 'TumorType', 'SampleType')
# ('Sex', 'Race', 'Site', 'Histology', 'SampleType', 'TumorType')
# ('Sex', 'Race', 'TumorType', 'Site', 'SampleType', 'Histology')
# ('Sex', 'Race', 'TumorType', 'Site', 'Histology', 'SampleType')
# ('Sex', 'Race', 'TumorType', 'SampleType', 'Site', 'Histology')
# ('Sex', 'Race', 'TumorType', 'SampleType', 'Histology', 'Site')
# ('Sex', 'Race', 'TumorType', 'Histology', 'Site', 'SampleType')
# ('Sex', 'Race', 'TumorType', 'Histology', 'SampleType', 'Site')
# ('Sex', 'Race', 'SampleType', 'Site', 'TumorType', 'Histology')
# ('Sex', 'Race', 'SampleType', 'Site', 'Histology', 'TumorType')
# ('Sex', 'Race', 'SampleType', 'TumorType', 'Site', 'Histology')
# ('Sex', 'Race', 'SampleType', 'TumorType', 'Histology', 'Site')
# ('Sex', 'Race', 'SampleType', 'Histology', 'Site', 'TumorType')
# ('Sex', 'Race', 'SampleType', 'Histology', 'TumorType', 'Site')
# ('Sex', 'Race', 'Histology', 'Site', 'TumorType', 'SampleType')
# ('Sex', 'Race', 'Histology', 'Site', 'SampleType', 'TumorType')
# ('Sex', 'Race', 'Histology', 'TumorType', 'Site', 'SampleType')
# ('Sex', 'Race', 'Histology', 'TumorType', 'SampleType', 'Site')
# ('Sex', 'Race', 'Histology', 'SampleType', 'Site', 'TumorType')
# ('Sex', 'Race', 'Histology', 'SampleType', 'TumorType', 'Site')
# ('Sex', 'Histology', 'Site', 'TumorType', 'SampleType', 'Race')
# ('Sex', 'Histology', 'Site', 'TumorType', 'Race', 'SampleType')
# ('Sex', 'Histology', 'Site', 'SampleType', 'TumorType', 'Race')
# ('Sex', 'Histology', 'Site', 'SampleType', 'Race', 'TumorType')
# ('Sex', 'Histology', 'Site', 'Race', 'TumorType', 'SampleType')
# ('Sex', 'Histology', 'Site', 'Race', 'SampleType', 'TumorType')
# ('Sex', 'Histology', 'TumorType', 'Site', 'SampleType', 'Race')
# ('Sex', 'Histology', 'TumorType', 'Site', 'Race', 'SampleType')
# ('Sex', 'Histology', 'TumorType', 'SampleType', 'Site', 'Race')
# ('Sex', 'Histology', 'TumorType', 'SampleType', 'Race', 'Site')
# ('Sex', 'Histology', 'TumorType', 'Race', 'Site', 'SampleType')
# ('Sex', 'Histology', 'TumorType', 'Race', 'SampleType', 'Site')
# ('Sex', 'Histology', 'SampleType', 'Site', 'TumorType', 'Race')
# ('Sex', 'Histology', 'SampleType', 'Site', 'Race', 'TumorType')
# ('Sex', 'Histology', 'SampleType', 'TumorType', 'Site', 'Race')
# ('Sex', 'Histology', 'SampleType', 'TumorType', 'Race', 'Site')
# ('Sex', 'Histology', 'SampleType', 'Race', 'Site', 'TumorType')
# ('Sex', 'Histology', 'SampleType', 'Race', 'TumorType', 'Site')
# ('Sex', 'Histology', 'Race', 'Site', 'TumorType', 'SampleType')
# ('Sex', 'Histology', 'Race', 'Site', 'SampleType', 'TumorType')
# ('Sex', 'Histology', 'Race', 'TumorType', 'Site', 'SampleType')
# ('Sex', 'Histology', 'Race', 'TumorType', 'SampleType', 'Site')
# ('Sex', 'Histology', 'Race', 'SampleType', 'Site', 'TumorType')
# ('Sex', 'Histology', 'Race', 'SampleType', 'TumorType', 'Site')
# ('Histology', 'Site', 'TumorType', 'SampleType', 'Race', 'Sex')
# ('Histology', 'Site', 'TumorType', 'SampleType', 'Sex', 'Race')
# ('Histology', 'Site', 'TumorType', 'Race', 'SampleType', 'Sex')
# ('Histology', 'Site', 'TumorType', 'Race', 'Sex', 'SampleType')
# ('Histology', 'Site', 'TumorType', 'Sex', 'SampleType', 'Race')
# ('Histology', 'Site', 'TumorType', 'Sex', 'Race', 'SampleType')
# ('Histology', 'Site', 'SampleType', 'TumorType', 'Race', 'Sex')
# ('Histology', 'Site', 'SampleType', 'TumorType', 'Sex', 'Race')
# ('Histology', 'Site', 'SampleType', 'Race', 'TumorType', 'Sex')
# ('Histology', 'Site', 'SampleType', 'Race', 'Sex', 'TumorType')
# ('Histology', 'Site', 'SampleType', 'Sex', 'TumorType', 'Race')
# ('Histology', 'Site', 'SampleType', 'Sex', 'Race', 'TumorType')
# ('Histology', 'Site', 'Race', 'TumorType', 'SampleType', 'Sex')
# ('Histology', 'Site', 'Race', 'TumorType', 'Sex', 'SampleType')
# ('Histology', 'Site', 'Race', 'SampleType', 'TumorType', 'Sex')
# ('Histology', 'Site', 'Race', 'SampleType', 'Sex', 'TumorType')
# ('Histology', 'Site', 'Race', 'Sex', 'TumorType', 'SampleType')
# ('Histology', 'Site', 'Race', 'Sex', 'SampleType', 'TumorType')
# ('Histology', 'Site', 'Sex', 'TumorType', 'SampleType', 'Race')
# ('Histology', 'Site', 'Sex', 'TumorType', 'Race', 'SampleType')
# ('Histology', 'Site', 'Sex', 'SampleType', 'TumorType', 'Race')
# ('Histology', 'Site', 'Sex', 'SampleType', 'Race', 'TumorType')
# ('Histology', 'Site', 'Sex', 'Race', 'TumorType', 'SampleType')
# ('Histology', 'Site', 'Sex', 'Race', 'SampleType', 'TumorType')
# ('Histology', 'TumorType', 'Site', 'SampleType', 'Race', 'Sex')
# ('Histology', 'TumorType', 'Site', 'SampleType', 'Sex', 'Race')
# ('Histology', 'TumorType', 'Site', 'Race', 'SampleType', 'Sex')
# ('Histology', 'TumorType', 'Site', 'Race', 'Sex', 'SampleType')
# ('Histology', 'TumorType', 'Site', 'Sex', 'SampleType', 'Race')
# ('Histology', 'TumorType', 'Site', 'Sex', 'Race', 'SampleType')
# ('Histology', 'TumorType', 'SampleType', 'Site', 'Race', 'Sex')
# ('Histology', 'TumorType', 'SampleType', 'Site', 'Sex', 'Race')
# ('Histology', 'TumorType', 'SampleType', 'Race', 'Site', 'Sex')
# ('Histology', 'TumorType', 'SampleType', 'Race', 'Sex', 'Site')
# ('Histology', 'TumorType', 'SampleType', 'Sex', 'Site', 'Race')
# ('Histology', 'TumorType', 'SampleType', 'Sex', 'Race', 'Site')
# ('Histology', 'TumorType', 'Race', 'Site', 'SampleType', 'Sex')
# ('Histology', 'TumorType', 'Race', 'Site', 'Sex', 'SampleType')
# ('Histology', 'TumorType', 'Race', 'SampleType', 'Site', 'Sex')
# ('Histology', 'TumorType', 'Race', 'SampleType', 'Sex', 'Site')
# ('Histology', 'TumorType', 'Race', 'Sex', 'Site', 'SampleType')
# ('Histology', 'TumorType', 'Race', 'Sex', 'SampleType', 'Site')
# ('Histology', 'TumorType', 'Sex', 'Site', 'SampleType', 'Race')
# ('Histology', 'TumorType', 'Sex', 'Site', 'Race', 'SampleType')
# ('Histology', 'TumorType', 'Sex', 'SampleType', 'Site', 'Race')
# ('Histology', 'TumorType', 'Sex', 'SampleType', 'Race', 'Site')
# ('Histology', 'TumorType', 'Sex', 'Race', 'Site', 'SampleType')
# ('Histology', 'TumorType', 'Sex', 'Race', 'SampleType', 'Site')
# ('Histology', 'SampleType', 'Site', 'TumorType', 'Race', 'Sex')
# ('Histology', 'SampleType', 'Site', 'TumorType', 'Sex', 'Race')
# ('Histology', 'SampleType', 'Site', 'Race', 'TumorType', 'Sex')
# ('Histology', 'SampleType', 'Site', 'Race', 'Sex', 'TumorType')
# ('Histology', 'SampleType', 'Site', 'Sex', 'TumorType', 'Race')
# ('Histology', 'SampleType', 'Site', 'Sex', 'Race', 'TumorType')
# ('Histology', 'SampleType', 'TumorType', 'Site', 'Race', 'Sex')
# ('Histology', 'SampleType', 'TumorType', 'Site', 'Sex', 'Race')
# ('Histology', 'SampleType', 'TumorType', 'Race', 'Site', 'Sex')
# ('Histology', 'SampleType', 'TumorType', 'Race', 'Sex', 'Site')
# ('Histology', 'SampleType', 'TumorType', 'Sex', 'Site', 'Race')
# ('Histology', 'SampleType', 'TumorType', 'Sex', 'Race', 'Site')
# ('Histology', 'SampleType', 'Race', 'Site', 'TumorType', 'Sex')
# ('Histology', 'SampleType', 'Race', 'Site', 'Sex', 'TumorType')
# ('Histology', 'SampleType', 'Race', 'TumorType', 'Site', 'Sex')
# ('Histology', 'SampleType', 'Race', 'TumorType', 'Sex', 'Site')
# ('Histology', 'SampleType', 'Race', 'Sex', 'Site', 'TumorType')
# ('Histology', 'SampleType', 'Race', 'Sex', 'TumorType', 'Site')
# ('Histology', 'SampleType', 'Sex', 'Site', 'TumorType', 'Race')
# ('Histology', 'SampleType', 'Sex', 'Site', 'Race', 'TumorType')
# ('Histology', 'SampleType', 'Sex', 'TumorType', 'Site', 'Race')
# ('Histology', 'SampleType', 'Sex', 'TumorType', 'Race', 'Site')
# ('Histology', 'SampleType', 'Sex', 'Race', 'Site', 'TumorType')
# ('Histology', 'SampleType', 'Sex', 'Race', 'TumorType', 'Site')
# ('Histology', 'Race', 'Site', 'TumorType', 'SampleType', 'Sex')
# ('Histology', 'Race', 'Site', 'TumorType', 'Sex', 'SampleType')
# ('Histology', 'Race', 'Site', 'SampleType', 'TumorType', 'Sex')
# ('Histology', 'Race', 'Site', 'SampleType', 'Sex', 'TumorType')
# ('Histology', 'Race', 'Site', 'Sex', 'TumorType', 'SampleType')
# ('Histology', 'Race', 'Site', 'Sex', 'SampleType', 'TumorType')
# ('Histology', 'Race', 'TumorType', 'Site', 'SampleType', 'Sex')
# ('Histology', 'Race', 'TumorType', 'Site', 'Sex', 'SampleType')
# ('Histology', 'Race', 'TumorType', 'SampleType', 'Site', 'Sex')
# ('Histology', 'Race', 'TumorType', 'SampleType', 'Sex', 'Site')
# ('Histology', 'Race', 'TumorType', 'Sex', 'Site', 'SampleType')
# ('Histology', 'Race', 'TumorType', 'Sex', 'SampleType', 'Site')
# ('Histology', 'Race', 'SampleType', 'Site', 'TumorType', 'Sex')
# ('Histology', 'Race', 'SampleType', 'Site', 'Sex', 'TumorType')
# ('Histology', 'Race', 'SampleType', 'TumorType', 'Site', 'Sex')
# ('Histology', 'Race', 'SampleType', 'TumorType', 'Sex', 'Site')
# ('Histology', 'Race', 'SampleType', 'Sex', 'Site', 'TumorType')
# ('Histology', 'Race', 'SampleType', 'Sex', 'TumorType', 'Site')
# ('Histology', 'Race', 'Sex', 'Site', 'TumorType', 'SampleType')
# ('Histology', 'Race', 'Sex', 'Site', 'SampleType', 'TumorType')
# ('Histology', 'Race', 'Sex', 'TumorType', 'Site', 'SampleType')
# ('Histology', 'Race', 'Sex', 'TumorType', 'SampleType', 'Site')
# ('Histology', 'Race', 'Sex', 'SampleType', 'Site', 'TumorType')
# ('Histology', 'Race', 'Sex', 'SampleType', 'TumorType', 'Site')
# ('Histology', 'Sex', 'Site', 'TumorType', 'SampleType', 'Race')
# ('Histology', 'Sex', 'Site', 'TumorType', 'Race', 'SampleType')
# ('Histology', 'Sex', 'Site', 'SampleType', 'TumorType', 'Race')
# ('Histology', 'Sex', 'Site', 'SampleType', 'Race', 'TumorType')
# ('Histology', 'Sex', 'Site', 'Race', 'TumorType', 'SampleType')
# ('Histology', 'Sex', 'Site', 'Race', 'SampleType', 'TumorType')
# ('Histology', 'Sex', 'TumorType', 'Site', 'SampleType', 'Race')
# ('Histology', 'Sex', 'TumorType', 'Site', 'Race', 'SampleType')
# ('Histology', 'Sex', 'TumorType', 'SampleType', 'Site', 'Race')
# ('Histology', 'Sex', 'TumorType', 'SampleType', 'Race', 'Site')
# ('Histology', 'Sex', 'TumorType', 'Race', 'Site', 'SampleType')
# ('Histology', 'Sex', 'TumorType', 'Race', 'SampleType', 'Site')
# ('Histology', 'Sex', 'SampleType', 'Site', 'TumorType', 'Race')
# ('Histology', 'Sex', 'SampleType', 'Site', 'Race', 'TumorType')
# ('Histology', 'Sex', 'SampleType', 'TumorType', 'Site', 'Race')
# ('Histology', 'Sex', 'SampleType', 'TumorType', 'Race', 'Site')
# ('Histology', 'Sex', 'SampleType', 'Race', 'Site', 'TumorType')
# ('Histology', 'Sex', 'SampleType', 'Race', 'TumorType', 'Site')
# ('Histology', 'Sex', 'Race', 'Site', 'TumorType', 'SampleType')
# ('Histology', 'Sex', 'Race', 'Site', 'SampleType', 'TumorType')
# ('Histology', 'Sex', 'Race', 'TumorType', 'Site', 'SampleType')
# ('Histology', 'Sex', 'Race', 'TumorType', 'SampleType', 'Site')
# ('Histology', 'Sex', 'Race', 'SampleType', 'Site', 'TumorType')
# ('Histology', 'Sex', 'Race', 'SampleType', 'TumorType', 'Site')
# /Users/mmckenna/Documents/Personal/cancer-decisiontree/venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 73
#      70 samples = pd.DataFrame(records)
#      72 # Predict probability
# ---> 73 probs = model.predict_proba(samples)
#      75 # Show probabilities for each class
#      76 print(f"{data.keys()} | {y}")
#
# File ~/Documents/Personal/cancer-decisiontree/venv/lib/python3.12/site-packages/sklearn/tree/_classes.py:1057, in DecisionTreeClassifier.predict_proba(self, X, check_input)
#    1033 """Predict class probabilities of the input samples X.
#    1034
#    1035 The predicted class probability is the fraction of samples of the same
#    (...)
#    1054     classes corresponds to that in the attribute :term:`classes_`.
#    1055 """
#    1056 check_is_fitted(self)
# -> 1057 X = self._validate_X_predict(X, check_input)
#    1058 proba = self.tree_.predict(X)
#    1060 if self.n_outputs_ == 1:
#
# File ~/Documents/Personal/cancer-decisiontree/venv/lib/python3.12/site-packages/sklearn/tree/_classes.py:489, in BaseDecisionTree._validate_X_predict(self, X, check_input)
#     487 else:
#     488     ensure_all_finite = True
# --> 489 X = validate_data(
#     490     self,
#     491     X,
#     492     dtype=DTYPE,
#     493     accept_sparse="csr",
#     494     reset=False,
#     495     ensure_all_finite=ensure_all_finite,
#     496 )
#     497 if issparse(X) and (
#     498     X.indices.dtype != np.intc or X.indptr.dtype != np.intc
#     499 ):
#     500     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File ~/Documents/Personal/cancer-decisiontree/venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2944, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2942         out = X, y
#    2943 elif not no_val_X and no_val_y:
# -> 2944     out = check_array(X, input_name="X", **check_params)
#    2945 elif no_val_X and not no_val_y:
#    2946     out = _check_y(y, **check_params)
#
# File ~/Documents/Personal/cancer-decisiontree/venv/lib/python3.12/site-packages/sklearn/utils/validation.py:931, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     927 pandas_requires_conversion = any(
#     928     _pandas_dtype_needs_early_conversion(i) for i in dtypes_orig
#     929 )
#     930 if all(isinstance(dtype_iter, np.dtype) for dtype_iter in dtypes_orig):
# --> 931     dtype_orig = np.result_type(*dtypes_orig)
#     932 elif pandas_requires_conversion and any(d == object for d in dtypes_orig):
#     933     # Force object if any of the dtypes is an object
#     934     dtype_orig = object
#
# ValueError: at least one array or dtype is required
